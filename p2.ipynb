# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Student_performance.csv")

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.describe().T
# Out:
#                    count       mean        std   min    25%   50%   75%    max
# raisedhands        480.0  46.908333  31.795995 -78.0  15.75  50.0  75.0  178.0
# VisITedResources   480.0  54.797917  33.080007   0.0  20.00  65.0  84.0   99.0
# AnnouncementsView  480.0  37.918750  26.611244   0.0  14.00  33.0  58.0   98.0
# Discussion         480.0  43.283333  27.637735   1.0  20.00  39.0  70.0   99.0

# %%
plt.figure(figsize=(24,16))
sns.boxplot(data=df,x='raisedhands',y='AnnouncementsView',hue='Class')
# Out:
# <AxesSubplot:xlabel='raisedhands', ylabel='AnnouncementsView'>

# %%
plt.figure(figsize=(24,16))
sns.boxplot(data=df,x='raisedhands',y='NationalITy',hue='gender')
# Out:
# <AxesSubplot:xlabel='raisedhands', ylabel='NationalITy'>

# %%
plt.figure(figsize=(24,16))
sns.boxplot(data=df,x='raisedhands',y='AnnouncementsView')
# Out:
# <AxesSubplot:xlabel='raisedhands', ylabel='AnnouncementsView'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
plt.figure(figsize=(24,16))
sns.boxplot(data=df,x='VisITedResources',y='Topic')
plt.show()

# %%
sns.scatterplot(data=df,x='VisITedResources',y='Discussion')
# Out:
# <AxesSubplot:xlabel='VisITedResources', ylabel='Discussion'>

# %%
mean=df['raisedhands'].mean()
mean
# Out:
# 46.90833333333333

# %%
std_dev=df['raisedhands'].std()
std_dev
# Out:
# 31.795995292361475

# %%
lower=mean-3*std_dev
lower
# Out:
# -48.47965254375109

# %%
upper=mean+3*std_dev
upper
# Out:
# 142.29631921041775

# %%
lowest=df['raisedhands'].min()
lowest
# Out:
# -78

# %%
highest=df['raisedhands'].max()
highest
# Out:
# 178

# %%
#z-score
zs=(df['raisedhands']-mean)/std_dev
zs
# Out:
# 0     -1.003533
# 1     -0.846281
# 2     -1.160786
# 3     -0.531776
# 4     -0.217271
#          ...
# 475   -1.318038
# 476    0.097234
# 477    0.254487
# 478   -0.531776
# 479   -0.374523
# Name: raisedhands, Length: 480, dtype: float64

# %%
zs.describe().T
# Out:
# count    4.800000e+02
# mean    -1.630640e-17
# std      1.000000e+00
# min     -3.928430e+00
# 25%     -9.799452e-01
# 50%      9.723447e-02
# 75%      8.834970e-01
# max      4.122899e+00
# Name: raisedhands, dtype: float64

# %%
zsoutliers=[]
for i in zs:
    if (i>3 or i<-3):
        zsoutliers.append(i)

# %%
zsoutliers
# Out:
# [4.122898668882352, -3.928429734147707]

# %%
lower
# Out:
# -48.47965254375109

# %%
upper
# Out:
# 142.29631921041775

# %%
outliers=[]
for i in df['raisedhands']:
    if (i>upper or i<lower):
        outliers.append(i)

# %%
outliers
# Out:
# [178, -78]

# %%
temp=zs
plt.figure(figsize=(18,10), dpi=100)
plt.plot(temp)
#plt.xticks([100,200,300,400])
plt.show()

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.908333         54.797917          37.918750   43.283333
# std      31.795995         33.080007          26.611244   27.637735
# min     -78.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     178.000000         99.000000          98.000000   99.000000

# %%
q1=df['raisedhands'].quantile(0.25)

# %%
q1
# Out:
# 15.75

# %%
q2=df['raisedhands'].quantile(0.5)
q2
# Out:
# 50.0

# %%
q3=df['raisedhands'].quantile(0.75)
q3
# Out:
# 75.0

# %%
iqr=q3-q1
iqr
# Out:
# 59.25

# %%
temp=df['raisedhands']
plt.figure(figsize=(18,10), dpi=100)
plt.plot(temp)
plt.xticks([100,200,300,400])
plt.show()

# %%
#locating the row where outliers occur.....
df.loc[df['raisedhands']==178]
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 16      M          KW       KuwaIT  MiddleSchool    G-07         B    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 16        F   Father          178                30                 20
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 16          80                    No                      Bad
#
#    StudentAbsenceDays Class
# 16            Above-7     M

# %%
outliers
# Out:
# [178, -78]

# %%
for i in outliers:
    tempvar=df.loc[df['raisedhands']==i]
    print(tempvar)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 16      M          KW       KuwaIT  MiddleSchool    G-07         B    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 16        F   Father          178                30                 20
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 16          80                    No                      Bad
#
#    StudentAbsenceDays Class
# 16            Above-7     M
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 38      M          KW       KuwaIT  MiddleSchool    G-06         A    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 38        F   Father          -78                 0                  0
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 38           4                    No                      Bad
#
#    StudentAbsenceDays Class
# 38            Above-7     L

# %%
df['raisedhands'].min()
# Out:
# -78

# %%
df['raisedhands'].max()
# Out:
# 178

# %%
df.shape
# Out:
# (480, 17)

# %%
for i in outliers:
    df.drop(df.loc[df['raisedhands']==i].index,inplace=True)

# %%
df.shape
# Out:
# (478, 17)

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %% [markdown]
# now we have successfully located the rows with outliers and removed them from our dataset
